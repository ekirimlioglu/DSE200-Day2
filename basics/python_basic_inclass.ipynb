# %% [markdown]
# ## First, let's connect to google drive...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
from datetime import datetime
from collections import defaultdict  #provide default values for null keys

from google.colab import drive #give colab access to google drive...
from google.colab import auth

auth.authenticate_user()
drive.mount('/content/drive')
thePath = '/content/drive/My Drive/Colab Notebooks/'

theCSV = pd.read_csv(thePath + 'temperatures.csv')
print(theCSV)
# Out:
# Mounted at /content/drive
#             date       city  temperature (C)
# 0     2023-07-20  San Diego             23.7
# 1     2023-05-19     Austin              NaN
# 2     2023-04-27        NaN             35.9
# 3     2023-07-03   New York             24.9
# 4     2023-06-02   New York              2.5
# ...          ...        ...              ...
# 4995  2023-12-16    Seattle              1.5
# 4996  2023-04-07  San Diego              8.1
# 4997  2023-03-14  San Diego             19.0
# 4998  2023-09-28    Phoenix              9.6
# 4999  2023-06-08    Phoenix             12.9
#
# [5000 rows x 3 columns]

# %% [markdown]
# ## Step 2: Let's read a set of monthly data from the CSV

# %%
monthly_data = defaultdict(list)
p = print

# Step 1: Read CSV file and organize data by month
with open(thePath + 'temperatures.csv') as file:
  theReader = csv.DictReader(file)
  theCols = theReader.fieldnames[:3]
  theMonthCol = theCols[2]
  for row in theReader:
    if all(row[col].strip() != '' for col in theCols ):
      theDate = datetime.strptime(row['date'], '%Y-%m-%d')
      theKey = theDate.strftime('%Y-%m')
      monthly_data[theKey].append(float(row[theMonthCol]))

p(monthly_data)

  #add code...
# Out:
# defaultdict(<class 'list'>, {'2023-07': [23.7, 24.9, 8.1, 38.3, 3.6, 30.1, 3.8, 39.9, 6.0, 37.8, 7.6, 27.3, 26.4, 4.0, 11.6, 30.2, 5.6, 30.8, 11.1, 7.7, 27.8, 24.7, 24.3, 9.3, 17.4, 11.2, 26.6, 11.2, 28.1, 5.7, 35.9, 37.2, 22.0, 0.1, 23.4, 30.9, 38.8, 18.5, 18.7, 30.4, 2.7, 2.7, 18.4, 3.0, 5.3, 16.7, 2.8, 3.0, 25.1, 11.8, 24.8, 7.1, 21.4, 15.1, 17.4, 8.0, 2.8, 18.6, 1.8, 19.5, 29.3, 39.4, 5.1, 3.3, 7.8, 5.8, 39.6, 7.0, 17.7, 20.4, 16.9, 12.3, 36.6, 3.6, 6.0, 20.2, 32.0, 18.2, 12.6, 24.9, 16.6, 12.6, 25.7, 9.2, 32.4, 31.0, 16.9, 7.0, 0.2, 0.4, 13.0, 33.6, 24.4, 3.2, 22.6, 25.6, 28.0, 26.5, 25.0, 18.1, 10.1, 8.5, 35.4, 10.4, 31.7, 19.6, 11.8, 36.3, 11.9, 38.8, 7.3, 10.7, 19.8, 0.3, 19.2, 21.1, 18.2, 8.0, 19.8, 22.4, 9.8, 36.5, 18.8, 38.9, 3.7, 8.6, 31.9, 24.1, 5.9, 5.0, 2.4, 22.7, 10.3, 6.2, 9.1, 39.2, 39.3, 10.9, 31.5, 18.9, 25.4, 19.3, 13.0, 31.4, 18.9, 16.1, 7.2, 26.8, 4.6, 26.6, 12.8, 19.5, 8.5, 13.8, 2.1, 15.2, 14.6, 14.4, 31.8, 22.8, 30.6, 18.6, 25.0, 1.1, 24.9, 18.5, 18.0, 36.8, 13.7, 11.9, 21.1, 10.9, 16.2, 6.6, 9.1, 2.5, 16.5, 29.6, 35.3, 10.9, 33.4, 2.5, 16.7, 22.3, 22.7, 5.9, 22.5, 18.8, 14.6, 13.0, 18.2, 23.6, 29.1, 37.8, 29.9, 20.1, 6.4, 9.3, 21.5, 34.5, 14.0, 0.9, 36.0, 26.9, 5.4, 10.2, 27.1, 21.8, 34.6, 3.8, 8.6, 37.3, 1.6, 28.8, 21.4, 8.4, 9.4, 25.5, 18.5, 9.5, 33.6, 19.0, 0.5, 23.1, 14.0, 1.4, 31.2, 37.6, 14.0, 11.9, 35.3, 27.0, 26.0, 24.6, 7.2, 20.5, 26.5, 16.0, 35.1, 25.9, 25.6, 8.0, 18.3, 27.2, 1.8, 8.0, 30.0, 1.6, 28.9, 37.1, 22.0, 4.7, 7.0, 7.5, 18.6, 16.3, 8.7, 33.9, 32.9, 11.0, 21.8, 13.9, 28.9, 25.4, 6.0, 7.7, 32.9, 7.4, 19.4, 34.7, 7.8, 3.7, 24.7, 14.6, 39.9, 6.9, 4.7, 9.0, 34.1, 26.7, 5.4, 10.9, 25.1, 13.2, 39.7, 23.9, 10.6, 36.5, 3.9, 29.3, 21.1, 35.1, 26.8, 33.3, 30.7, 8.3, 19.7, 24.8, 24.2, 13.9, 18.0, 4.1, 25.8, 23.9, 10.2, 4.5, 13.7, 24.6, 5.1, 20.3, 37.0, 28.1, 9.8, 0.4, 7.9, 6.7, 7.7, 32.5, 9.2, 21.0, 36.1, 22.9, 22.0, 11.6, 36.1, 22.9, 10.5, 5.4, 14.6, 7.2, 19.9, 38.0, 5.3, 35.9], '2023-06': [2.5, 26.1, 13.6, 20.3, 28.0, 13.9, 16.0, 7.9, 27.9, 12.1, 30.5, 6.7, 8.9, 8.1, 15.1, 16.7, 10.8, 21.4, 35.2, 20.7, 20.6, 24.7, 27.1, 28.5, 7.1, 1.8, 26.7, 33.2, 13.6, 27.4, 9.8, 0.4, 33.0, 14.3, 21.0, 14.3, 31.5, 4.6, 26.5, 11.4, 19.8, 24.4, 23.4, 26.8, 33.2, 3.8, 12.3, 0.6, 19.3, 27.5, 22.1, 20.6, 21.2, 34.5, 26.0, 32.8, 30.1, 9.7, 8.3, 19.4, 0.8, 22.1, 33.6, 39.7, 10.7, 36.5, 8.6, 1.0, 33.7, 4.3, 13.6, 21.5, 8.9, 36.8, 33.6, 18.0, 35.6, 13.4, 22.6, 28.0, 9.3, 8.4, 12.3, 2.7, 6.5, 3.8, 19.0, 2.1, 9.8, 18.2, 0.3, 32.8, 33.9, 37.4, 16.6, 13.5, 17.6, 6.5, 37.7, 19.7, 38.9, 15.6, 11.7, 21.5, 7.9, 22.9, 37.6, 32.9, 5.8, 38.5, 32.4, 3.4, 35.8, 0.3, 23.1, 5.3, 14.4, 29.7, 15.8, 4.9, 5.6, 11.6, 28.0, 37.8, 25.9, 29.9, 26.0, 18.1, 7.5, 7.0, 38.8, 1.2, 22.3, 19.8, 17.7, 28.3, 12.3, 1.0, 37.1, 20.5, 12.8, 26.6, 2.9, 10.3, 28.4, 25.9, 8.0, 11.1, 2.2, 28.4, 31.1, 18.1, 6.2, 39.7, 37.1, 23.0, 27.5, 8.7, 5.8, 35.9, 22.1, 38.7, 19.6, 33.0, 13.4, 35.3, 29.9, 2.7, 25.9, 33.1, 10.7, 13.0, 26.0, 14.0, 25.5, 23.5, 5.4, 35.5, 39.7, 21.1, 7.9, 32.1, 21.0, 21.1, 20.8, 12.2, 28.5, 20.6, 4.5, 35.2, 38.5, 33.9, 27.4, 20.2, 13.9, 16.5, 12.8, 38.6, 33.2, 16.7, 30.5, 14.1, 6.5, 9.4, 31.6, 17.9, 27.3, 24.7, 28.3, 7.2, 23.6, 23.6, 31.5, 7.7, 14.1, 30.7, 14.3, 18.5, 11.1, 29.3, 9.0, 39.9, 10.9, 38.5, 40.0, 26.9, 10.1, 30.8, 30.9, 16.9, 26.0, 8.2, 37.4, 25.4, 33.5, 36.9, 22.6, 35.6, 21.9, 14.7, 31.1, 12.3, 8.7, 22.8, 26.5, 22.9, 33.4, 15.7, 35.4, 8.4, 27.5, 39.1, 14.9, 39.2, 21.0, 30.0, 15.5, 13.4, 14.3, 6.9, 11.0, 18.9, 32.2, 11.2, 7.8, 5.4, 38.2, 28.0, 30.1, 7.5, 31.8, 32.5, 37.4, 35.8, 27.4, 4.4, 4.9, 32.4, 21.8, 37.4, 30.4, 8.3, 8.2, 4.3, 28.5, 15.5, 20.3, 27.1, 24.5, 19.3, 12.9], '2023-12': [1.7, 2.7, 28.6, 24.6, 27.8, 19.3, 36.4, 11.1, 19.8, 31.5, 28.0, 26.3, 12.2, 25.6, 33.4, 8.2, 9.0, 7.6, 17.8, 3.0, 26.9, 5.4, 36.7, 35.1, 38.7, 35.1, 25.2, 28.6, 3.5, 10.7, 36.2, 25.5, 36.2, 11.2, 5.1, 33.3, 33.4, 30.5, 29.4, 16.5, 28.7, 26.8, 26.0, 10.4, 4.9, 0.1, 11.5, 24.5, 2.4, 17.6, 35.2, 0.8, 18.0, 6.1, 2.2, 32.9, 34.1, 27.7, 23.3, 16.4, 33. ...

# %% [markdown]
# ## Step 3: Let's gather and order the monthly stats

# %%
#capture avg, min, max data for each date...

monthly_stats = []

#add code...
for theDate, temps in monthly_data.items():
  avg_temp = sum(temps) / len(temps)
  min_temp = min(temps)
  max_temp = max(temps)
  monthly_stats.append((theDate, avg_temp, min_temp, max_temp))

monthly_stats.sort() #sort it...

p(monthly_stats)

#fetch some data for our plots

months = [month for month, _, _ ,_ in monthly_stats]
avg_temps = [avg_temp for _, avg_temp, _, _ in monthly_stats]
# Out:
# [('2023-01', 20.579153094462537, 0.5, 39.9), ('2023-02', 19.78712121212122, 0.0, 39.8), ('2023-03', 19.738111888111895, 0.0, 40.0), ('2023-04', 20.914705882352944, 0.0, 39.9), ('2023-05', 20.99612903225805, 0.2, 39.9), ('2023-06', 20.575257731958743, 0.3, 40.0), ('2023-07', 18.42664670658682, 0.1, 39.9), ('2023-08', 18.860596026490057, 0.0, 39.7), ('2023-09', 19.880936454849497, 0.0, 40.0), ('2023-10', 19.72686567164178, 0.2, 40.0), ('2023-11', 18.667365269461058, 0.0, 40.0), ('2023-12', 19.037898089171986, 0.1, 39.9)]

# %% [markdown]
# ## Step 4: Let's visualize some data...

# %%
# Now write the actual plot code

plt.figure(figsize=(10, 5))

plt.plot(months, avg_temps, marker='o')
plt.xlabel('xMonth')
plt.ylabel('Average Temperature')
plt.title('Average Temperature')
plt.grid(True, color='#8844bb', alpha=0.2)
plt.xticks(rotation=45)
plt.tight_layout
plt.show()

# %% [markdown]
# ## Just for fun, lets save some data...

# %%
# Step 4: Save the results to a new CSV file
output_path = 'monthly_temperature_stats_plain_python.csv'

with open(output_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Month', 'Average Temperature', 'Min Temperature', 'Max Temperature'])
    writer.writerows(monthly_stats)

# Display the calculated monthly statistics to the user
monthly_stats
# Out:
# [('2023-01', 20.579153094462537, 0.5, 39.9),
#  ('2023-02', 19.78712121212122, 0.0, 39.8),
#  ('2023-03', 19.738111888111895, 0.0, 40.0),
#  ('2023-04', 20.914705882352944, 0.0, 39.9),
#  ('2023-05', 20.99612903225805, 0.2, 39.9),
#  ('2023-06', 20.575257731958743, 0.3, 40.0),
#  ('2023-07', 18.42664670658682, 0.1, 39.9),
#  ('2023-08', 18.860596026490057, 0.0, 39.7),
#  ('2023-09', 19.880936454849497, 0.0, 40.0),
#  ('2023-10', 19.72686567164178, 0.2, 40.0),
#  ('2023-11', 18.667365269461058, 0.0, 40.0),
#  ('2023-12', 19.037898089171986, 0.1, 39.9)]
